# %%
# Load needed Python modules
import netCDF4
import matplotlib.pyplot as plt
import os
import astropy
import numpy as np
from astropy.convolution import convolve as ap_convolve
from astropy.convolution import Box2DKernel
from netCDF4 import num2date
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Change to SSD with files
os.chdir('/nfs/cnhlab003/cnh')

for filename in os.listdir('mur-sst'):
    if filename[:6] == '201111':

        # Create "handle" to access netCDF file
        tFile = netCDF4.Dataset('mur-sst/'+filename)

        # Extract data from file
        sst=tFile['analysed_sst']
        date_num = tFile['time'][:]
        units = tFile.variables['time'].units
        date = num2date(date_num, units)[0]
        date = str(date)
        date = date[:10]

        # Determine latitude and longitude range
        lat_n = 15000
        lat_s = 10800
        lon_e = 3500
        lon_w = 1000
        
        # Extract a subregion
        sstReg=sst[0, lat_s:lat_n, lon_w:lon_e]-273.
        
        # Extract coordinate data
        lat = tFile.variables['lat']
        lon = tFile.variables['lon']
        lat_min = lat.valid_min
        lon_min = lon.valid_min
        lat_min = (11800/100) + lat_min
        lon_min = (2500/100) + lon_min
        lat_max = lat.valid_max
        lon_max = lon.valid_max
        lat_max = (11800/100) + lat_max
        lon_max = (2500/100) + lon_max
        lon_dif = lon_e-lon_w
        lat_dif = lat_n-lat_s
        
        # Make sst plot
        ax = plt.subplot(131)
        fig1 = plt.imshow(sstReg,origin='lower',cmap='prism')
        plt.xticks([0, lon_dif/2, lon_dif], [lon_min, ((lon_max-lon_min)/2)+lon_min, lon_max])
        plt.yticks([0, lat_dif/2, lat_dif], [lat_min, lat_min+lat_dif, lat_max])
        plt.title("SST")
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        plt.colorbar(fig1, cax=cax)
        
        # Convolve
        box_2D_kernel = Box2DKernel(9)
        nan=float('nan')
        sstReg=np.ma.filled(sstReg,nan)
        sstReg[ :, 0]=nan
        sstReg[ 0, :]=nan
        sstReg[ :,-1]=nan
        sstReg[-1, :]=nan
        sstReg2=ap_convolve(sstReg, box_2D_kernel)
        dd=sstReg2
        dd=dd[9:-9, 9:-9]
        dd=np.ma.masked_invalid(dd)
        ddmean=np.mean(dd)
        ddstd=np.std(dd)
        dd=dd-ddmean
        
        # Make convolve plot
        ax = plt.subplot(132)
        fig2 = plt.imshow(dd,origin='lower',cmap='prism')
        plt.title("Convolved SST")
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        plt.colorbar(fig2, cax=cax)
        
        # Make difference plot
        ax = plt.subplot(133)
        sstReg=sstReg[9:-9, 9:-9]
        dif = sstReg - dd

        fig3 = plt.imshow(dif,origin='lower',cmap='prism')
        plt.title("Difference")
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        plt.colorbar(fig3, cax=cax)
        
        # Format plots
        plt.suptitle(date, y=0.9, fontsize=16)
        plt.subplots_adjust(wspace = 0.95)
        
        # Save and show fig
        os.chdir('/home/culberta/bef-aft-dif-imgs')
        plt.savefig(str(date) + '.png', dpi = 180)
        plt.show()
        plt.clf()
        os.chdir('/nfs/cnhlab003/cnh')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d5909d896dd0> in <module>()
#      57         sstReg[ :,-1]=nan
#      58         sstReg[-1, :]=nan
# ---> 59         sstReg2=ap_convolve(sstReg, box_2D_kernel)
#      60         dd=sstReg2
#      61         dd=dd[9:-9, 9:-9]
#
# ~/hill-2018/miniconda3/envs/pangeo/lib/python3.6/site-packages/astropy/utils/decorators.py in convolve(array, kernel, boundary, fill_value, nan_treatment, normalize_kernel, mask, preserve_nan, normalization_zero_tol)
#     825             name = func.__name__
#     826
# --> 827         func = make_function_with_signature(func, name=name, **wrapped_args)
#     828         func = functools.update_wrapper(func, wrapped, assigned=assigned,
#     829                                         updated=updated)
#
# ~/hill-2018/miniconda3/envs/pangeo/lib/python3.6/site-packages/astropy/nddata/decorators.py in wrapper(data, *args, **kwargs)
#     243                                   AstropyUserWarning)
#     244
# --> 245             result = func(data, *args, **kwargs)
#     246
#     247             if unpack and repack:
#
# ~/hill-2018/miniconda3/envs/pangeo/lib/python3.6/site-packages/astropy/convolution/convolve.py in convolve(array, kernel, boundary, fill_value, nan_treatment, normalize_kernel, mask, preserve_nan, normalization_zero_tol)
#     257                                               kernel_internal,
#     258                                               float(fill_value),
# --> 259                                               renormalize_by_kernel,
#     260                                              )
#     261         elif boundary == 'wrap':
#
# KeyboardInterrupt:
